# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
base_url = "https://www.jackjones.in/jackets-jj"
response=requests.get(base_url)

# %%
soup=BeautifulSoup(response.content,'html.parser')

# %%
elements = soup.find_all('div', class_=["product-thumb","size-option"])

# %%
dir(elements[0])
# Out:
# ['DEFAULT_INTERESTING_STRING_TYPES',
#  'EMPTY_ELEMENT_EVENT',
#  'END_ELEMENT_EVENT',
#  'START_ELEMENT_EVENT',
#  'STRING_ELEMENT_EVENT',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_clone',
#  '_event_stream',
#  '_find_all',
#  '_find_one',
#  '_format_tag',
#  '_indent_string',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_namespaces',
#  '_should_pretty_print',
# ...

# %%
elements[0]
# Out:
# <div class="product-thumb size-option">
# <div class="image image-swap-effect" style="position: relative;">
# <!-- Quantity Left -->
# <div class="stock_left" style="visibility:hidden;"></div>
# <!-- Quantity Left ends -->
# <a class="single-product" href="https://www.jackjones.in/jackets-jj/272442201-racing-red" onclick="return productClick('408908');" target="_blank">
# ...

# %%
from bs4 import BeautifulSoup

# ... (Your HTML for the entire page containing multiple products)

soup = BeautifulSoup(html_content, 'html.parser')

catalog = {"image_url": [], "price": [], "name": []}

# Get all product containers
product_containers = soup.find_all('div', class_='product-thumb size-option')

for container in product_containers:
   # Extract image URL
   image_tag = container.find('img', class_='swap-image lload img-responsive')
   image_url = image_tag['data-src']
   catalog["image_url"].append(image_url)

   # Extract product name
   product_name_link = container.find('h4', class_='product-name').find('a')
   product_name = product_name_link.text.strip()
   catalog["name"].append(product_name)

   # Extract cost (assuming price-new has the discounted price)
   price_tag = container.find('span', class_='price-new')
   cost = price_tag.text.strip()[3:] 
   catalog["price"].append(cost)

print(catalog)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/gudikotieswarmani/ecommerce/preprocessing/collection.ipynb Cell 7 line 1
#      <a href='vscode-notebook-cell://970-cs-102728529812-default.cs-asia-southeast1-yelo.cloudshell.dev/home/gudikotieswarmani/ecommerce/preprocessing/collection.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> for container in product_containers:
#      <a href='vscode-notebook-cell://970-cs-102728529812-default.cs-asia-southeast1-yelo.cloudshell.dev/home/gudikotieswarmani/ecommerce/preprocessing/collection.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>    # Extract image URL
# ...

# %%
from bs4 import BeautifulSoup

# ... (Your HTML for the entire page containing multiple products)

soup = BeautifulSoup(requests.get("https://www.jackjones.in/jackets-jj").content, 'html.parser')

catalog = {"image_url": [], "price": [], "name": []}

# Get all product containers
product_containers = soup.find_all('div', class_='product-thumb size-option')

for container in product_containers:
   # Extract image URL
   image_tag = container.find('img', class_='swap-image lload img-responsive')
   image_url = image_tag['data-src']
   catalog["image_url"].append(image_url)

   # Extract product name
   product_name_link = container.find('h4', class_='product-name').find('a')
   product_name = product_name_link.text.strip()
   catalog["name"].append(product_name)

   # Extract cost (assuming price-new has the discounted price)
   price_tag = container.find('span', class_='price-new')
   cost = price_tag.text.strip()[3:] 
   catalog["price"].append(cost)

print(catalog)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/gudikotieswarmani/ecommerce/preprocessing/collection.ipynb Cell 8 line 2
#      <a href='vscode-notebook-cell://970-cs-102728529812-default.cs-asia-southeast1-yelo.cloudshell.dev/home/gudikotieswarmani/ecommerce/preprocessing/collection.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a>    # Extract cost (assuming price-new has the discounted price)
#      <a href='vscode-notebook-cell://970-cs-102728529812-default.cs-asia-southeast1-yelo.cloudshell.dev/home/gudikotieswarmani/ecommerce/preprocessing/collection.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>    price_tag = container.find('span', class_='price-new')
# ...

# %%
soup=BeautifulSoup(requests.get("https://www.jackjones.in/jackets-jj/230321501-navy-blazer").content,'html.parser')

# %%
soup.find_all("p")[2].text.strip()
# Out:
# "Men's knit casual jacket in a colourblocked pattern. Made from premium quality cotton, with a quilted front, cuffed hem, ribbed bomber-styled collar, zip-up closure, and full sleeves."

# %%
link=soup.find_all("a",class_="single-product")

# %%
# Out:
# [<a class="single-product" href="https://www.jackjones.in/jackets-jj/272442201-racing-red" onclick="return productClick('408908');" target="_blank">
#  <img alt="URBAN RACERS by JACK&amp;JONES RED RACER LEATHER JACKET" class="swap-image lload img-responsive" data-src="https://images.bestsellerclothing.in/data/JJ/16-aug-2023/272442201_g2.jpg?width=415&amp;height=550&amp;mode=fill&amp;fill=blur&amp;format=auto" height="550" loading="lazy" src="https://images.bestsellerclothing.in/loader-500x635.gif?width=415&amp;height=550&amp;mode=fill&amp;fill=blur&amp;format=auto" style="position:absolute" width="415"> <img alt="URBAN RACERS by JACK&amp;JONES RED RACER LEATHER JACKET" class="lload img-responsive" height="550" loading="lazy" src="https://images.bestsellerclothing.in/data/JJ/16-aug-2023/272442201_g1.jpg?width=415&amp;height=550&amp;mode=fill&amp;fill=blur&amp;format=auto" title="URBAN RACERS by JACK&amp;JONES RED RACER LEATHER JACKET" width="415"/>
#  </img></a>,
# ...
