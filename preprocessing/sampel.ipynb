# %%
import pandas as pd
import json

# %%
df=pd.read_json("catalog.json")

# %%
df.to_json("catalog-record.csv",orient="records")

# %%
result = {
    "data": df.to_dict(orient='records')
}

# %%
with open("new-catalog.json","w") as f:
      f.write(json.dumps(result,indent=4))

# %%
df
# Out:
#                                           product_name  price    category  \
# 0                      Black Formal Full Sleeves Shirt    999      shirts
# 1    UNMATCHED by JACK&JONES Blue Check Cut & Sew S...   6999      shirts
# 2                        Peach Knit Full Sleeves Shirt   2999      shirts
# 3    UNMATCHED by JACK&JONES White Striped Colourbl...   4999      shirts
# 4    UNMATCHED by JACK&JONES Black Print-Blocked Cu...   6999      shirts
# ..                                                 ...    ...         ...
# 189                               Black Leather Wallet   1999     wallets
# 190                               Black Leather Wallet   1299     wallets
# 191                               Brown Leather Wallet   1299     wallets
# 192                           Brown Aviator Sunglasses    999  sunglasses
# 193                           Green Aviator Sunglasses   1749  sunglasses
#
#                                            description  \
# ...
